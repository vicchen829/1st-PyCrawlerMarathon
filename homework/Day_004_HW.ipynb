# %% [markdown]
# # 利用 Python 存取 API
# 了解 Server Client 的架構與溝通方法
# 知道 HTTP Request & Response 的內容
# 什麼是 API？如何用 Python 程式存取 API 資料
# # 下載檔案

# %%
import requests

r=requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11035769055","type":"DeleteEvent","actor":{"id":92044,"login":"jcoyne","display_login":"jcoyne","gravatar_id":"","url":"https://api.github.com/users/jcoyne","avatar_url":"https://avatars.githubusercontent.com/u/92044?"},"repo":{"id":22521770,"name":"sul-dlss/pre-assembly","url":"https://api.github.com/repos/sul-dlss/pre-assembly"},"payload":{"ref":"simplify_setup","ref_type":"branch","pusher_type":"user"},"public":true,"created_at":"2019-12-07T16:01:10Z","org":{"id":230583,"login":"sul-dlss","gravatar_id":"","url":"https://api.github.com/orgs/sul-dlss","avatar_url":"https://avatars.githubusercontent.com/u/230583?"}},{"id":"11035769051","type":"PushEvent","actor":{"id":5219207,"login":"jdetaeye","display_login":"jdetaeye","gravatar_id":"","url":"https://api.github.com/users/jdetaeye","avatar_url":"https://avatars.githubusercontent.com/u/5219207?"},"repo":{"id":12776324,"name":"frePPLe/frepple","url":"https://api.github.com/repos/frePPLe/frepple"},"payload":{"push_id":4368160223,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"5782cdc49d8057482f846800b6a0229f2d93bdea","before":"05a65894ca5862ca60ca0a108c00b0c441f9f054","commits":[{"sha":"5782cdc49d8057482f846800b6a0229f2d93bdea","author":{"email":"jdetaeye@frepple.com","name":"Johan De Taeye"},"message":"small update to plantask class","distinct":true,"url":"https://api.github.com/repos/frePPLe/frepple/commits/5782cdc49d8057482f846800b6a0229f2d93bdea"}]},"public":true,"created_at":"2019-12-07T16:01:10Z","org":{"id":9384034,"login":"frePPLe","gravatar_id":"","url":"https://api.github.com/orgs/frePPLe","avatar_url":"https://avatars.githubusercontent.com/u/9384034?"}},{"id":"11035769049","type":"PushEvent","actor":{"id":45690915,"login":"longbuivan","display_login":"longbuivan","gravatar_id":"","url":"https://api.github.com/users/longbuivan","avatar_url":"https://avatars.githubusercontent.com/u/45690915?"},"repo":{"id":226463887,"name":"longbuivan/tiki_scrapper_db","url":"https://api.github.com/repos/longbuivan/tiki_scrapper_db"},"payload":{"push_id":4368160222,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"5c17b461ec8c689a8417a740fdaddced518603ff","before":"206910c3e55542eb171d02b87313c1eb226f79cb","commits":[{"sha":"5c17b461ec8c689a8417a740fdaddced518603ff","author":{"email":"longbuivan95@gmail.com","name":"longbuivan"},"message":"more info","distinct":true,"url":"https://api.github.com/repos/longbuivan/tiki_scrapper_db/commits/5c17b461ec8c689a8417a740fdaddced518603ff"}]},"public":true,"created_at":"2019-12-07T16:01:10Z"},{"id":"11035769046","type":"PushEvent","actor":{"id":43611660,"login":"dikac","display_login":"dikac","gravatar_id":"","url":"https://api.github.com/users/dikac","avatar_url":"https://avatars.githubusercontent.com/u/43611660?"},"repo":{"id":224474272,"name":"sibtechcoid/wika-aims-api-library","url":"https://api.github.com/repos/sibtechcoid/wika-aims-api-library"},"payload":{"push_id":4368160220,"size":1,"distinct_size":1,"ref":"refs/heads/development","head":"53cf16e73edb427f3ebc3747128c35e4c1206329","before":"a41397d8d20b2b292d1e8ec097cc3939739e22b1","commits":[{"sha":"53cf16e73edb427f3ebc3747128c35e4c1206329","author":{"email":"rigel234@yahoo.com","name":"dikac"},"message":"fix statusDate name","distinct":true,"url":"https://api.github.com/repos/sibtechcoid/wika-aims-api-library/commits/53cf16e73edb427f3ebc3747128c35e4c1206329"}]},"public":true,"created_at":"2019-12-07T16:01:10Z"},{"id":"11035769048","type":"WatchEvent","actor":{"id":22261092,"login":"mynttt","display_login":"mynttt","gravatar_id":"","url":"https://api.github.com/users/mynttt","avatar_url":"https://avatars.githubusercontent.com/u/22261092?"},"repo":{"id":218525951,"name":"brunomnsilva/JavaFXSmartGraph","url":"https://api.github.com/repos/brunomnsilva/JavaFXSmartGraph"},"payload":{"action":"started"},"public":true,"created_at":"2019-12-07T16:01:10Z"},{"id":"11035769047","type":"CreateEvent","actor":{"id":30029208,"login":"talatkuyuk","display_login":"talatkuyu ...

# %%
r.text[0]
# Out:
# '['

# %%
import json
json.loads(r.text)
# Out:
# [{'id': '11035769055',
#   'type': 'DeleteEvent',
#   'actor': {'id': 92044,
#    'login': 'jcoyne',
#    'display_login': 'jcoyne',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jcoyne',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92044?'},
#   'repo': {'id': 22521770,
#    'name': 'sul-dlss/pre-assembly',
#    'url': 'https://api.github.com/repos/sul-dlss/pre-assembly'},
#   'payload': {'ref': 'simplify_setup',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-07T16:01:10Z',
#   'org': {'id': 230583,
#    'login': 'sul-dlss',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/sul-dlss',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/230583?'}},
#  {'id': '11035769051',
#   'type': 'PushEvent',
#   'actor': {'id': 5219207,
#    'login': 'jdetaeye',
#    'display_login': 'jdetaeye',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jdetaeye',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5219207?'},
#   'repo': {'id': 12776324,
#    'name': 'frePPLe/frepple',
#    'url': 'https://api.github.com/repos/frePPLe/frepple'},
#   'payload': {'push_id': 4368160223,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5782cdc49d8057482f846800b6a0229f2d93bdea',
#    'before': '05a65894ca5862ca60ca0a108c00b0c441f9f054',
#    'commits': [{'sha': '5782cdc49d8057482f846800b6a0229f2d93bdea',
#      'author': {'email': 'jdetaeye@frepple.com', 'name': 'Johan De Taeye'},
#      'message': 'small update to plantask class',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/frePPLe/frepple/commits/5782cdc49d8057482f846800b6a0229f2d93bdea'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:10Z',
#   'org': {'id': 9384034,
#    'login': 'frePPLe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/frePPLe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9384034?'}},
#  {'id': '11035769049',
#   'type': 'PushEvent',
#   'actor': {'id': 45690915,
#    'login': 'longbuivan',
#    'display_login': 'longbuivan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/longbuivan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45690915?'},
#   'repo': {'id': 226463887,
#    'name': 'longbuivan/tiki_scrapper_db',
#    'url': 'https://api.github.com/repos/longbuivan/tiki_scrapper_db'},
#   'payload': {'push_id': 4368160222,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5c17b461ec8c689a8417a740fdaddced518603ff',
#    'before': '206910c3e55542eb171d02b87313c1eb226f79cb',
#    'commits': [{'sha': '5c17b461ec8c689a8417a740fdaddced518603ff',
#      'author': {'email': 'longbuivan95@gmail.com', 'name': 'longbuivan'},
#      'message': 'more info',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/longbuivan/tiki_scrapper_db/commits/5c17b461ec8c689a8417a740fdaddced518603ff'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:10Z'},
#  {'id': '11035769046',
#   'type': 'PushEvent',
#   'actor': {'id': 43611660,
#    'login': 'dikac',
#    'display_login': 'dikac',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dikac',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43611660?'},
#   'repo': {'id': 224474272,
#    'name': 'sibtechcoid/wika-aims-api-library',
#    'url': 'https://api.github.com/repos/sibtechcoid/wika-aims-api-library'},
#   'payload': {'push_id': 4368160220,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/development',
#    'head': '53cf16e73edb427f3ebc3747128c35e4c1206329',
#    'before': 'a41397d8d20b2b292d1e8ec097cc3939739e22b1',
#    'commits': [{'sha': '53cf16e73edb427f3ebc3747128c35e4c1206329',
#      'author': {'email': 'rigel234@yahoo.com', 'name': 'dikac'},
#      'message': 'fix statusDate name',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sibtechcoid/wika-aims-api-library/commits/53cf16e73edb427f3ebc3747128c35e4c1206329'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:10Z'},
#  {'id': '11035769048',
#   'type': 'WatchEvent',
#   'actor': {'id': 22261092,
#    'login': 'mynttt',
#    'display_login': 'mynttt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mynttt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22261092?'},
#   'repo': {'id': 218525951,
#    'name': 'brunomnsilva/JavaFXSmartGraph',
#    'url': 'https://api.github.com/repos/brunomnsilva/JavaFXSmartGraph'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-07T16:01:10Z'},
#  {'id': '11035769047',
#   'type': 'CreateEvent',
#   'actor': {'id': 30029208,
#    'login': 'talatkuyuk',
#    'display_login': 'talatkuyuk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/talatkuyuk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30029208?'},
#   'repo': {'id': 226539311,
#    'name': 'talatkuyuk/hello-world',
#    'url': 'https://api.github.com/repos/talatkuyuk/hello-world'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'This is a traditional hello-world action for github.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-07T16:01:10Z'},
#  {'id': '11035769039',
#   'type': 'PushEvent',
#   'actor': {'id': 35137611,
#    'login': 'onionhub',
#    'display_login': 'onionhub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/onionhub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35137611?'},
#   'repo': {'id': 225834080,
#    'name': 'onionhub/TIP',
#    'url': 'https://api.github.com/repos/onionhub/TIP'},
#   'payload': {'push_id': 4368160213,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b617ccf2c03bf680e51160af43a2e2e5699314a0',
#    'before': '322985153275dd05177b0f49d45cda134d042f49',
#    'commits': [{'sha': 'b617ccf2c03bf680e51160af43a2e2e5699314a0',
#      'author': {'email': '35137611+onionhub@users.noreply.github.com',
#       'name': 'onionhub'},
#      'message': 'Update Parameters.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/onionhub/TIP/commits/b617ccf2c03bf680e51160af43a2e2e5699314a0'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:10Z'},
#  {'id': '11035769037',
#   'type': 'PushEvent',
#   'actor': {'id': 44620067,
#    'login': 'schwatter',
#    'display_login': 'schwatter',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/schwatter',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44620067?'},
#   'repo': {'id': 157124777,
#    'name': 'schwatter/fhemfrontend-enigma2',
#    'url': 'https://api.github.com/repos/schwatter/fhemfrontend-enigma2'},
#   'payload': {'push_id': 4368160209,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '906612f31c2e915f87a2f51f6287ebe0ba83ac2d',
#    'before': 'bf73b8538938eca5e5266346ae1dd5c0876e629c',
#    'commits': [{'sha': '906612f31c2e915f87a2f51f6287ebe0ba83ac2d',
#      'author': {'email': '44620067+schwatter@users.noreply.github.com',
#       'name': 'schwatter'},
#      'message': 'switch to urllib3\n\nSolved my https encoding problem. Almost fast or fast like httplib.\nBut Post is stil httplib.\nGo away requests. Not bad, but too\nslow for me.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/schwatter/fhemfrontend-enigma2/commits/906612f31c2e915f87a2f51f6287ebe0ba83ac2d'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:10Z'},
#  {'id': '11035769033',
#   'type': 'PushEvent',
#   'actor': {'id': 26039414,
#    'login': 'VovaGrigorev',
#    'display_login': 'VovaGrigorev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/VovaGrigorev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26039414?'},
#   'repo': {'id': 225919627,
#    'name': 'VovaGrigorev/self-made.github.io',
#    'url': 'https://api.github.com/repos/VovaGrigorev/self-made.github.io'},
#   'payload': {'push_id': 4368160211,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd32d0beeb54568d37a333d0cd6f5ac8d06f48f79',
#    'before': 'a967dd3b6bf2a723f39523198b1ff79b96bb06f3',
#    'commits': [{'sha': 'd32d0beeb54568d37a333d0cd6f5ac8d06f48f79',
#      'author': {'email': 'grigorevv191@gmail.com', 'name': 'VovaGrigorev'},
#      'message': 'Update style.css',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/VovaGrigorev/self-made.github.io/commits/d32d0beeb54568d37a333d0cd6f5ac8d06f48f79'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:10Z'},
#  {'id': '11035769032',
#   'type': 'PushEvent',
#   'actor': {'id': 34366878,
#    'login': 'niepengsmile',
#    'display_login': 'niepengsmile',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/niepengsmile',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34366878?'},
#   'repo': {'id': 124726377,
#    'name': 'niepengsmile/niepengsmile.github.io',
#    'url': 'https://api.github.com/repos/niepengsmile/niepengsmile.github.io'},
#   'payload': {'push_id': 4368160208,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a02012aad551f54dde123fba45a2ac10885052dc',
#    'before': 'e984add5c7dbf175e7493b8bbff614a9c52ae46f',
#    'commits': [{'sha': 'a02012aad551f54dde123fba45a2ac10885052dc',
#      'author': {'email': 'niepeng521@126.com', 'name': '聂澎'},
#      'message': 'Site updated: 2019-12-08 00:00:43',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/niepengsmile/niepengsmile.github.io/commits/a02012aad551f54dde123fba45a2ac10885052dc'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:10Z'},
#  {'id': '11035769030',
#   'type': 'PushEvent',
#   'actor': {'id': 57104294,
#    'login': 'PineappleStrawberry',
#    'display_login': 'PineappleStrawberry',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PineappleStrawberry',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57104294?'},
#   'repo': {'id': 226049576,
#    'name': 'PineappleStrawberry/leo',
#    'url': 'https://api.github.com/repos/PineappleStrawberry/leo'},
#   'payload': {'push_id': 4368160207,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1933ed30e6e476300a3492353db0aa7527d1626a',
#    'before': '691dd9ea40ac697390f94bb4f3b4ece9c706d324',
#    'commits': [{'sha': '1933ed30e6e476300a3492353db0aa7527d1626a',
#      'author': {'email': '57104294+PineappleStrawberry@users.noreply.github.com',
#       'name': 'LeonardoDiCaprio'},
#      'message': 'Update environment.yml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PineappleStrawberry/leo/commits/1933ed30e6e476300a3492353db0aa7527d1626a'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:10Z'},
#  {'id': '11035769021',
#   'type': 'PushEvent',
#   'actor': {'id': 1253239,
#    'login': 'ShiftyAxel',
#    'display_login': 'ShiftyAxel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ShiftyAxel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1253239?'},
#   'repo': {'id': 224946052,
#    'name': 'ShiftyAxel/Qodot',
#    'url': 'https://api.github.com/repos/ShiftyAxel/Qodot'},
#   'payload': {'push_id': 4368160203,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8bc3fbe581cfcd72063edaeb6e7d26f129f921d5',
#    'before': '23e83c9db6ac5a5ebe73a9e870c6662f0bbb6eeb',
#    'commits': [{'sha': '8bc3fbe581cfcd72063edaeb6e7d26f129f921d5',
#      'author': {'email': 'jpalmerwatkins@gmail.com', 'name': 'Josh Palmer'},
#      'message': 'Implement QodotPrinter, add src/util folder',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ShiftyAxel/Qodot/commits/8bc3fbe581cfcd72063edaeb6e7d26f129f921d5'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:09Z'},
#  {'id': '11035769023',
#   'type': 'WatchEvent',
#   'actor': {'id': 956287,
#    'login': 'milenkovicm',
#    'display_login': 'milenkovicm',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/milenkovicm',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/956287?'},
#   'repo': {'id': 72286208,
#    'name': 'fede1024/rust-rdkafka',
#    'url': 'https://api.github.com/repos/fede1024/rust-rdkafka'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-07T16:01:10Z'},
#  {'id': '11035769018',
#   'type': 'PushEvent',
#   'actor': {'id': 34989448,
#    'login': 'eddddddy',
#    'display_login': 'eddddddy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eddddddy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34989448?'},
#   'repo': {'id': 225080135,
#    'name': 'eddddddy/AdventOfCode2019',
#    'url': 'https://api.github.com/repos/eddddddy/AdventOfCode2019'},
#   'payload': {'push_id': 4368160199,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '54e41befadcd826d1e977db8edfd45a951cf9b89',
#    'before': 'afb5da7d41d25286fd164eb6860705ebe223690e',
#    'commits': [{'sha': '54e41befadcd826d1e977db8edfd45a951cf9b89',
#      'author': {'email': 'eddy3.14159@gmail.com', 'name': 'eddddddy'},
#      'message': 'Add day 7 solution',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eddddddy/AdventOfCode2019/commits/54e41befadcd826d1e977db8edfd45a951cf9b89'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:09Z'},
#  {'id': '11035769017',
#   'type': 'CreateEvent',
#   'actor': {'id': 12740301,
#    'login': 'Tetriminos',
#    'display_login': 'Tetriminos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Tetriminos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12740301?'},
#   'repo': {'id': 226539313,
#    'name': 'Tetriminos/advent-of-code-2019',
#    'url': 'https://api.github.com/repos/Tetriminos/advent-of-code-2019'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-07T16:01:09Z'},
#  {'id': '11035769011',
#   'type': 'PushEvent',
#   'actor': {'id': 40300642,
#    'login': 'tgadiev',
#    'display_login': 'tgadiev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tgadiev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40300642?'},
#   'repo': {'id': 226117744,
#    'name': 'lean-delivery/ansible-beats',
#    'url': 'https://api.github.com/repos/lean-delivery/ansible-beats'},
#   'payload': {'push_id': 4368160195,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/molecule',
#    'head': '9f9ee10fb0047a55eef2980a309c32f9e35cb3b5',
#    'before': '06b0b0ad60cf65bcf2a570a05ad0f82bfd8199b5',
#    'commits': [{'sha': '9f9ee10fb0047a55eef2980a309c32f9e35cb3b5',
#      'author': {'email': 'Timur_Gadiev@epam.com', 'name': 'Timur Gadiev'},
#      'message': 'Adjust price\n\nSigned-off-by: Timur Gadiev <Timur_Gadiev@epam.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lean-delivery/ansible-beats/commits/9f9ee10fb0047a55eef2980a309c32f9e35cb3b5'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:09Z',
#   'org': {'id': 40624609,
#    'login': 'lean-delivery',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/lean-delivery',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40624609?'}},
#  {'id': '11035769009',
#   'type': 'PushEvent',
#   'actor': {'id': 15963917,
#    'login': 'bushub',
#    'display_login': 'bushub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bushub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15963917?'},
#   'repo': {'id': 214915135,
#    'name': 'bushub/hosts',
#    'url': 'https://api.github.com/repos/bushub/hosts'},
#   'payload': {'push_id': 4368160193,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'af2bcb55677ba592161c444b3acd4c413115a5ab',
#    'before': 'c24e38a12f31a0d889a72269bdf0ec300fbf7d8a',
#    'commits': [{'sha': 'af2bcb55677ba592161c444b3acd4c413115a5ab',
#      'author': {'email': 'admin@example.com', 'name': 'admin'},
#      'message': 'content update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bushub/hosts/commits/af2bcb55677ba592161c444b3acd4c413115a5ab'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:09Z'},
#  {'id': '11035769002',
#   'type': 'PushEvent',
#   'actor': {'id': 23053399,
#    'login': 'martinwu42',
#    'display_login': 'martinwu42',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinwu42',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23053399?'},
#   'repo': {'id': 149771055,
#    'name': 'martinwu42/pkubbsbackup',
#    'url': 'https://api.github.com/repos/martinwu42/pkubbsbackup'},
#   'payload': {'push_id': 4368160187,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd8f13d6cd06fb3fd679f3d8457b8db1f812b2631',
#    'before': '85535da49b05adf2020a2c69922fe0c0f7a1a7e5',
#    'commits': [{'sha': 'd8f13d6cd06fb3fd679f3d8457b8db1f812b2631',
#      'author': {'email': 'martinwu42@outlook.com', 'name': 'wd'},
#      'message': '此外，还有围困我们的四道墙壁。',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/martinwu42/pkubbsbackup/commits/d8f13d6cd06fb3fd679f3d8457b8db1f812b2631'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:09Z'},
#  {'id': '11035769004',
#   'type': 'PushEvent',
#   'actor': {'id': 40586421,
#    'login': 'himobi',
#    'display_login': 'himobi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/himobi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40586421?'},
#   'repo': {'id': 138676186,
#    'name': 'himobi/hotspot',
#    'url': 'https://api.github.com/repos/himobi/hotspot'},
#   'payload': {'push_id': 4368160185,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a259584e5d669c6c7a3eb2267050e13e2320a39f',
#    'before': '039761fda00d9aea55bb8274339a2fb5eea30f7d',
#    'commits': [{'sha': 'a259584e5d669c6c7a3eb2267050e13e2320a39f',
#      'author': {'email': '40586421+himobi@users.noreply.github.com',
#       'name': 'himobi'},
#      'message': 'thank you',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/himobi/hotspot/commits/a259584e5d669c6c7a3eb2267050e13e2320a39f'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:09Z'},
#  {'id': '11035769005',
#   'type': 'CreateEvent',
#   'actor': {'id': 57808454,
#    'login': 'kain0821',
#    'display_login': 'kain0821',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kain0821',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57808454?'},
#   'repo': {'id': 222047015,
#    'name': 'kain0821/study',
#    'url': 'https://api.github.com/repos/kain0821/study'},
#   'payload': {'ref': 'blog',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-07T16:01:09Z'},
#  {'id': '11035768997',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 38195368,
#    'login': 'kossy0701',
#    'display_login': 'kossy0701',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kossy0701',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38195368?'},
#   'repo': {'id': 226517821,
#    'name': 'kossy0701/otenki',
#    'url': 'https://api.github.com/repos/kossy0701/otenki'},
#   'payload': {'action': 'opened',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/kossy0701/otenki/pulls/1',
#     'id': 350322841,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzUwMzIyODQx',
#     'html_url': 'https://github.com/kossy0701/otenki/pull/1',
#     'diff_url': 'https://github.com/kossy0701/otenki/pull/1.diff',
#     'patch_url': 'https://github.com/kossy0701/otenki/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/kossy0701/otenki/issues/1',
#     'number': 1,
#     'state': 'open',
#     'locked': False,
#     'title': 'create home, area-edit and forecast components',
#     'user': {'login': 'kossy0701',
#      'id': 38195368,
#      'node_id': 'MDQ6VXNlcjM4MTk1MzY4',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/38195368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/kossy0701',
#      'html_url': 'https://github.com/kossy0701',
#      'followers_url': 'https://api.github.com/users/kossy0701/followers',
#      'following_url': 'https://api.github.com/users/kossy0701/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/kossy0701/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/kossy0701/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/kossy0701/subscriptions',
#      'organizations_url': 'https://api.github.com/users/kossy0701/orgs',
#      'repos_url': 'https://api.github.com/users/kossy0701/repos',
#      'events_url': 'https://api.github.com/users/kossy0701/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/kossy0701/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '## WHAT\r\n\r\n- create component skeltons\r\n\r\n## WHY\r\n\r\n- prepare implement',
#     'created_at': '2019-12-07T16:01:08Z',
#     'updated_at': '2019-12-07T16:01:08Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/kossy0701/otenki/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/kossy0701/otenki/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/kossy0701/otenki/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/kossy0701/otenki/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/kossy0701/otenki/statuses/943d7119e8dab5e406e6c95268f4267a46f6dbc3',
#     'head': {'label': 'kossy0701:add-main-components',
#      'ref': 'add-main-components',
#      'sha': '943d7119e8dab5e406e6c95268f4267a46f6dbc3',
#      'user': {'login': 'kossy0701',
#       'id': 38195368,
#       'node_id': 'MDQ6VXNlcjM4MTk1MzY4',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/38195368?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kossy0701',
#       'html_url': 'https://github.com/kossy0701',
#       'followers_url': 'https://api.github.com/users/kossy0701/followers',
#       'following_url': 'https://api.github.com/users/kossy0701/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kossy0701/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kossy0701/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kossy0701/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kossy0701/orgs',
#       'repos_url': 'https://api.github.com/users/kossy0701/repos',
#       'events_url': 'https://api.github.com/users/kossy0701/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kossy0701/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 226517821,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjY1MTc4MjE=',
#       'name': 'otenki',
#       'full_name': 'kossy0701/otenki',
#       'private': False,
#       'owner': {'login': 'kossy0701',
#        'id': 38195368,
#        'node_id': 'MDQ6VXNlcjM4MTk1MzY4',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/38195368?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kossy0701',
#        'html_url': 'https://github.com/kossy0701',
#        'followers_url': 'https://api.github.com/users/kossy0701/followers',
#        'following_url': 'https://api.github.com/users/kossy0701/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kossy0701/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kossy0701/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kossy0701/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kossy0701/orgs',
#        'repos_url': 'https://api.github.com/users/kossy0701/repos',
#        'events_url': 'https://api.github.com/users/kossy0701/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kossy0701/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/kossy0701/otenki',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/kossy0701/otenki',
#       'forks_url': 'https://api.github.com/repos/kossy0701/otenki/forks',
#       'keys_url': 'https://api.github.com/repos/kossy0701/otenki/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kossy0701/otenki/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kossy0701/otenki/teams',
#       'hooks_url': 'https://api.github.com/repos/kossy0701/otenki/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kossy0701/otenki/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kossy0701/otenki/events',
#       'assignees_url': 'https://api.github.com/repos/kossy0701/otenki/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kossy0701/otenki/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kossy0701/otenki/tags',
#       'blobs_url': 'https://api.github.com/repos/kossy0701/otenki/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kossy0701/otenki/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kossy0701/otenki/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/kossy0701/otenki/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kossy0701/otenki/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kossy0701/otenki/languages',
#       'stargazers_url': 'https://api.github.com/repos/kossy0701/otenki/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kossy0701/otenki/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kossy0701/otenki/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kossy0701/otenki/subscription',
#       'commits_url': 'https://api.github.com/repos/kossy0701/otenki/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kossy0701/otenki/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kossy0701/otenki/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kossy0701/otenki/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kossy0701/otenki/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kossy0701/otenki/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kossy0701/otenki/merges',
#       'archive_url': 'https://api.github.com/repos/kossy0701/otenki/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kossy0701/otenki/downloads',
#       'issues_url': 'https://api.github.com/repos/kossy0701/otenki/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kossy0701/otenki/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kossy0701/otenki/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kossy0701/otenki/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kossy0701/otenki/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kossy0701/otenki/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kossy0701/otenki/deployments',
#       'created_at': '2019-12-07T13:28:43Z',
#       'updated_at': '2019-12-07T13:30:54Z',
#       'pushed_at': '2019-12-07T16:00:29Z',
#       'git_url': 'git://github.com/kossy0701/otenki.git',
#       'ssh_url': 'git@github.com:kossy0701/otenki.git',
#       'clone_url': 'https://github.com/kossy0701/otenki.git',
#       'svn_url': 'https://github.com/kossy0701/otenki',
#       'homepage': None,
#       'size': 100,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'development'}},
#     'base': {'label': 'kossy0701:development',
#      'ref': 'development',
#      'sha': '2ea0af06f7c03ebb50848b95e516b3029a7b20ae',
#      'user': {'login': 'kossy0701',
#       'id': 38195368,
#       'node_id': 'MDQ6VXNlcjM4MTk1MzY4',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/38195368?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kossy0701',
#       'html_url': 'https://github.com/kossy0701',
#       'followers_url': 'https://api.github.com/users/kossy0701/followers',
#       'following_url': 'https://api.github.com/users/kossy0701/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kossy0701/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kossy0701/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kossy0701/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kossy0701/orgs',
#       'repos_url': 'https://api.github.com/users/kossy0701/repos',
#       'events_url': 'https://api.github.com/users/kossy0701/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kossy0701/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 226517821,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjY1MTc4MjE=',
#       'name': 'otenki',
#       'full_name': 'kossy0701/otenki',
#       'private': False,
#       'owner': {'login': 'kossy0701',
#        'id': 38195368,
#        'node_id': 'MDQ6VXNlcjM4MTk1MzY4',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/38195368?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kossy0701',
#        'html_url': 'https://github.com/kossy0701',
#        'followers_url': 'https://api.github.com/users/kossy0701/followers',
#        'following_url': 'https://api.github.com/users/kossy0701/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kossy0701/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kossy0701/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kossy0701/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kossy0701/orgs',
#        'repos_url': 'https://api.github.com/users/kossy0701/repos',
#        'events_url': 'https://api.github.com/users/kossy0701/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kossy0701/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/kossy0701/otenki',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/kossy0701/otenki',
#       'forks_url': 'https://api.github.com/repos/kossy0701/otenki/forks',
#       'keys_url': 'https://api.github.com/repos/kossy0701/otenki/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kossy0701/otenki/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kossy0701/otenki/teams',
#       'hooks_url': 'https://api.github.com/repos/kossy0701/otenki/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kossy0701/otenki/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kossy0701/otenki/events',
#       'assignees_url': 'https://api.github.com/repos/kossy0701/otenki/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kossy0701/otenki/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kossy0701/otenki/tags',
#       'blobs_url': 'https://api.github.com/repos/kossy0701/otenki/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kossy0701/otenki/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kossy0701/otenki/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/kossy0701/otenki/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kossy0701/otenki/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kossy0701/otenki/languages',
#       'stargazers_url': 'https://api.github.com/repos/kossy0701/otenki/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kossy0701/otenki/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kossy0701/otenki/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kossy0701/otenki/subscription',
#       'commits_url': 'https://api.github.com/repos/kossy0701/otenki/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kossy0701/otenki/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kossy0701/otenki/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kossy0701/otenki/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kossy0701/otenki/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kossy0701/otenki/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kossy0701/otenki/merges',
#       'archive_url': 'https://api.github.com/repos/kossy0701/otenki/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kossy0701/otenki/downloads',
#       'issues_url': 'https://api.github.com/repos/kossy0701/otenki/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kossy0701/otenki/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kossy0701/otenki/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kossy0701/otenki/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kossy0701/otenki/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kossy0701/otenki/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kossy0701/otenki/deployments',
#       'created_at': '2019-12-07T13:28:43Z',
#       'updated_at': '2019-12-07T13:30:54Z',
#       'pushed_at': '2019-12-07T16:00:29Z',
#       'git_url': 'git://github.com/kossy0701/otenki.git',
#       'ssh_url': 'git@github.com:kossy0701/otenki.git',
#       'clone_url': 'https://github.com/kossy0701/otenki.git',
#       'svn_url': 'https://github.com/kossy0701/otenki',
#       'homepage': None,
#       'size': 100,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'development'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/kossy0701/otenki/pulls/1'},
#      'html': {'href': 'https://github.com/kossy0701/otenki/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/kossy0701/otenki/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/kossy0701/otenki/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/kossy0701/otenki/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/kossy0701/otenki/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/kossy0701/otenki/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/kossy0701/otenki/statuses/943d7119e8dab5e406e6c95268f4267a46f6dbc3'}},
#     'author_association': 'OWNER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 123,
#     'deletions': 0,
#     'changed_files': 12}},
#   'public': True,
#   'created_at': '2019-12-07T16:01:09Z'},
#  {'id': '11035768992',
#   'type': 'WatchEvent',
#   'actor': {'id': 6511667,
#    'login': 'xiao201261',
#    'display_login': 'xiao201261',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xiao201261',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6511667?'},
#   'repo': {'id': 32118589,
#    'name': 'SolidZORO/zpix-pixel-font',
#    'url': 'https://api.github.com/repos/SolidZORO/zpix-pixel-font'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-07T16:01:09Z'},
#  {'id': '11035768987',
#   'type': 'PushEvent',
#   'actor': {'id': 49725537,
#    'login': 'paulgrote',
#    'display_login': 'paulgrote',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulgrote',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49725537?'},
#   'repo': {'id': 181916846,
#    'name': 'paulgrote/python-practice',
#    'url': 'https://api.github.com/repos/paulgrote/python-practice'},
#   'payload': {'push_id': 4368160176,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3121b60d1ac36567b19f7db2981f61ff6d747bae',
#    'before': '28ef90c583598e3e86c9cb2da4849654a6a83885',
#    'commits': [{'sha': '3121b60d1ac36567b19f7db2981f61ff6d747bae',
#      'author': {'email': '49725537+paulgrote@users.noreply.github.com',
#       'name': 'paulgrote'},
#      'message': 'practice',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/paulgrote/python-practice/commits/3121b60d1ac36567b19f7db2981f61ff6d747bae'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:09Z'},
#  {'id': '11035768986',
#   'type': 'PushEvent',
#   'actor': {'id': 11215289,
#    'login': 'keksobot',
#    'display_login': 'keksobot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/keksobot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11215289?'},
#   'repo': {'id': 222746816,
#    'name': 'htmlacademy-ecmascript/1075187-taskmanager-10',
#    'url': 'https://api.github.com/repos/htmlacademy-ecmascript/1075187-taskmanager-10'},
#   'payload': {'push_id': 4368160173,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '2551042caed6ce577387e862fc084a4b60f4caca',
#    'before': '1cb2ea97c2a91581226eeec245b5d9c5d1cd3f31',
#    'commits': [{'sha': '7310a51a72f255d8292750424b030bf127c2722e',
#      'author': {'email': 'grigorievka@gmail.com', 'name': 'grigorievk'},
#      'message': 'Change function to class. Refactoring for render function. Add change task to task-edit view.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/htmlacademy-ecmascript/1075187-taskmanager-10/commits/7310a51a72f255d8292750424b030bf127c2722e'},
#     {'sha': '2551042caed6ce577387e862fc084a4b60f4caca',
#      'author': {'email': 'keksobot@users.noreply.github.com', 'name': 'Keks'},
#      'message': 'Merge pull request #6 from grigorievk/module4-task1',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/htmlacademy-ecmascript/1075187-taskmanager-10/commits/2551042caed6ce577387e862fc084a4b60f4caca'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:09Z',
#   'org': {'id': 22890904,
#    'login': 'htmlacademy-ecmascript',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/htmlacademy-ecmascript',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22890904?'}},
#  {'id': '11035768983',
#   'type': 'CreateEvent',
#   'actor': {'id': 30029208,
#    'login': 'talatkuyuk',
#    'display_login': 'talatkuyuk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/talatkuyuk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30029208?'},
#   'repo': {'id': 226539311,
#    'name': 'talatkuyuk/hello-world',
#    'url': 'https://api.github.com/repos/talatkuyuk/hello-world'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'This is a traditional hello-world action for github.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-07T16:01:08Z'},
#  {'id': '11035768979',
#   'type': 'PushEvent',
#   'actor': {'id': 30173326,
#    'login': 'chloir',
#    'display_login': 'chloir',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chloir',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30173326?'},
#   'repo': {'id': 226534794,
#    'name': 'chloir/Board',
#    'url': 'https://api.github.com/repos/chloir/Board'},
#   'payload': {'push_id': 4368160168,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8d19140d18eb8633185b782f220e8e6c1311cd4f',
#    'before': '41eb328be778e7dfafde169b8494951415c7505a',
#    'commits': [{'sha': '8d19140d18eb8633185b782f220e8e6c1311cd4f',
#      'author': {'email': 'chloir.sharp@gmail.com', 'name': 'Reki Yamashita'},
#      'message': 'Update vendor.json',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/chloir/Board/commits/8d19140d18eb8633185b782f220e8e6c1311cd4f'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:08Z'},
#  {'id': '11035768977',
#   'type': 'PushEvent',
#   'actor': {'id': 36294582,
#    'login': 'wangzeyao',
#    'display_login': 'wangzeyao',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wangzeyao',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36294582?'},
#   'repo': {'id': 211477673,
#    'name': 'wangzeyao/wangzeyao.github.io',
#    'url': 'https://api.github.com/repos/wangzeyao/wangzeyao.github.io'},
#   'payload': {'push_id': 4368160171,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '853c6268c44e1426e1e8a4557c228247b9c588a5',
#    'before': '4a84d58559c953e87541e9cd29ab740d1714ff64',
#    'commits': [{'sha': '853c6268c44e1426e1e8a4557c228247b9c588a5',
#      'author': {'email': 'zeyao.wang@etu.unice.fr', 'name': 'wangzeyao'},
#      'message': 'Site updated: 2019-12-07 17:00:48',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wangzeyao/wangzeyao.github.io/commits/853c6268c44e1426e1e8a4557c228247b9c588a5'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:08Z'},
#  {'id': '11035768980',
#   'type': 'WatchEvent',
#   'actor': {'id': 29523614,
#    'login': 'PerhapsSomeone',
#    'display_login': 'PerhapsSomeone',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PerhapsSomeone',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29523614?'},
#   'repo': {'id': 55386834,
#    'name': 'antonpup/Aurora',
#    'url': 'https://api.github.com/repos/antonpup/Aurora'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-07T16:01:08Z'},
#  {'id': '11035768975',
#   'type': 'PushEvent',
#   'actor': {'id': 57423276,
#    'login': 'tbanish',
#    'display_login': 'tbanish',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tbanish',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57423276?'},
#   'repo': {'id': 224876706,
#    'name': 'tbanish/apples-and-holidays-online-web-sp-000',
#    'url': 'https://api.github.com/repos/tbanish/apples-and-holidays-online-web-sp-000'},
#   'payload': {'push_id': 4368160170,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': 'f3772f9383cd1491fb13b52b57d7381f14bd9c86',
#    'before': 'bd0c4cd0d59003abbe2de5ded722272417f005e3',
#    'commits': [{'sha': 'f3772f9383cd1491fb13b52b57d7381f14bd9c86',
#      'author': {'email': 'tombanish@gmail.com', 'name': 'Tom Banish'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tbanish/apples-and-holidays-online-web-sp-000/commits/f3772f9383cd1491fb13b52b57d7381f14bd9c86'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:08Z'},
#  {'id': '11035768978',
#   'type': 'PushEvent',
#   'actor': {'id': 53569830,
#    'login': 'PortableSAM',
#    'display_login': 'PortableSAM',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PortableSAM',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53569830?'},
#   'repo': {'id': 224074568,
#    'name': 'PortableSAM/totoy22',
#    'url': 'https://api.github.com/repos/PortableSAM/totoy22'},
#   'payload': {'push_id': 4368160169,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ff73a93d49c6f90f706606229c17fd3ae2ea7171',
#    'before': '48988c48cb2f6e8bd4eb3076a2a494016ee0e0c7',
#    'commits': [{'sha': 'ff73a93d49c6f90f706606229c17fd3ae2ea7171',
#      'author': {'email': '53569830+Lee-h-saem@users.noreply.github.com',
#       'name': 'Lee-h-saem'},
#      'message': 'TargetDt Update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PortableSAM/totoy22/commits/ff73a93d49c6f90f706606229c17fd3ae2ea7171'}]},
#   'public': True,
#   'created_at': '2019-12-07T16:01:08Z'}]

# %%
json.loads(r.text)[0]
# Out:
# {'id': '11035769055',
#  'type': 'DeleteEvent',
#  'actor': {'id': 92044,
#   'login': 'jcoyne',
#   'display_login': 'jcoyne',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jcoyne',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/92044?'},
#  'repo': {'id': 22521770,
#   'name': 'sul-dlss/pre-assembly',
#   'url': 'https://api.github.com/repos/sul-dlss/pre-assembly'},
#  'payload': {'ref': 'simplify_setup',
#   'ref_type': 'branch',
#   'pusher_type': 'user'},
#  'public': True,
#  'created_at': '2019-12-07T16:01:10Z',
#  'org': {'id': 230583,
#   'login': 'sul-dlss',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/orgs/sul-dlss',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/230583?'}}

# %% [markdown]
# # 其它用法

# %%
payload={'key1':'value1','key2':'value2'}
r=requests.get('http://httpbin.org/get',params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0'},
#  'origin': '218.35.173.115, 218.35.173.115',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r=requests.post('http://httpbin.org/post',data={'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0'},
#  'json': None,
#  'origin': '218.35.173.115, 218.35.173.115',
#  'url': 'https://httpbin.org/post'}

# %% [markdown]
# # 利用 Python 存取 API
# 了解 Server Client 的架構與溝通方法
# 知道 HTTP Request & Response 的內容
# 什麼是 API？如何用 Python 程式存取 API 資料
# # 作業目標
# 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
# https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# # 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
'''
r.text:是str文字
json.loads(r.text):保留list結構
'''
# Out:
# '\nr.text:是str文字\njson.loads(r.text):保留list結構\n'

# %% [markdown]
# # 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容

# %%
a=requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(a.text)
# Out:
# {'all': [{'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58f9b96132ffea00208fe9b7',
#    'text': 'rerewr',
#    'type': 'cat',
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
#    'text': "Cats don't go through menopause, so they can continue to breed into their senior years.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c470572a99c3f00140fe4bd',
#    'text': 'Cats like being brushed by their owners, because it reminds them of their mother.',
#    'type': 'cat',
#    'user': {'_id': '5c470492a99c3f00140fe4bc',
#     'name': {'first': 'David', 'last': 'Gippner'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475ca8a99c3f00140fe4d0',
#    'text': 'Loyal, playful, and alert, Manx are considered to be more "doglike" than other cats.',
# ...
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de0a5d32abaa900154956c9',
#    'type': 'cat',
#    'text': 'This is the first time.',
#    'user': {'_id': '5de0a5b02abaa900154956c8',
#     'name': {'first': 'Sushen', 'last': 'Biswas'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de608922c455b00153df05d',
#    'type': 'cat',
#    'text': 'Coba cat nyata.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de6090e2c455b00153df05e',
#    'type': 'cat',
#    'text': 'Cats has no hands.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de609812c455b00153df05f',
#    'type': 'cat',
#    'text': 'Testing aja.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'type': 'cat',
#    'text': 'More than half of the world’s felines don’t respond to catnip.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de7808a0013130015a3ccb0',
#    'type': 'cat',
#    'text': 'The wealthiest cat in the world is named Blackie.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780a00013130015a3ccb1',
#    'type': 'cat',
#    'text': 'A group of kittens is called a Kindle.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780d30013130015a3ccb2',
#    'type': 'cat',
#    'text': 'In October 1983, a cat named "Félicette" became the first cat in space.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780e60013130015a3ccb3',
#    'type': 'cat',
#    'text': 'Cats can be allergic to humans.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5deb725edeb28e00158cd804',
#    'type': 'cat',
#    'text': 'Cats are nuts.',
#    'user': {'_id': '5deb723adeb28e00158cd803',
#     'name': {'first': 'Trip Store', 'last': 'Krabi'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
json.loads(a.text)['all'][0]
# Out:
# {'_id': '58e008b80aac31001185ed0d',
#  'text': 'Adult cats only meow to communicate with humans.',
#  'type': 'cat',
#  'user': {'_id': '58e007480aac31001185ecef',
#   'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#  'upvotes': 4,
#  'userUpvoted': None}

# %%
b=requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
json.loads(b.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1680H004',
#    'WaterLevel': 1.09},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '2560H025',
#    'WaterLevel': 3.73},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '2370H024',
#    'WaterLevel': 195.43},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1660H013',
#    'WaterLevel': 0.87},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1650H009',
#    'WaterLevel': 0.09},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1650H011',
#    'WaterLevel': 0.29},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '2420H024',
#    'WaterLevel': 4.83},
#   {'RecordTime': 'Dec 7, 2019 11:50:00 PM',
#    'StationIdentifier': '1630H032',
#    'WaterLevel': 0.12},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1850H005',
#    'WaterLevel': 22.14},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '2420H018',
#    'WaterLevel': 156.32},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1650H006',
#    'WaterLevel': 1.24},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1730H074',
#    'WaterLevel': 245.48},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1730H062',
#    'WaterLevel': 41.77},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1740H011',
#    'WaterLevel': 6.61},
#   {'RecordTime': 'Dec 7, 2019 11:50:00 PM',
#    'StationIdentifier': '1630H029',
#    'WaterLevel': 5.12},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '2370H018',
#    'WaterLevel': 124.1},
#   {'RecordTime': 'Dec 7, 2019 11:20:00 PM',
#    'StationIdentifier': '1630H035',
#    'WaterLevel': 402.49},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1730H069',
#    'WaterLevel': 140.97},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1670H003',
#    'WaterLevel': 0.21},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1740H009',
#    'WaterLevel': 32.35},
#   {'RecordTime': 'Dec 7, 2019 11:50:00 PM',
#    'StationIdentifier': '1630H028',
#    'WaterLevel': 10.26},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '2370H016',
#    'WaterLevel': 167.94},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '2200H022',
#    'WaterLevel': 161.21},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1630H024',
#    'WaterLevel': 69.1},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1730H065',
#    'WaterLevel': 90.74},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1660H011',
#    'WaterLevel': 1.5},
#   {'RecordTime': 'Dec 8, 2019 12:10:00 AM',
#    'StationIdentifier': '1740H002',
#    'WaterLevel': 4.41},
#   {'RecordTime': 'Dec 7, 2019 11:50:00 PM',
#    'StationIdentifier': '1630H026',
#    'WaterLevel': 44.53},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '2200H028',
#    'WaterLevel': 278.11},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '2200H011',
#    'WaterLevel': 25.79},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1590H013',
#    'WaterLevel': 20.81},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1730H058',
#    'WaterLevel': 113.93},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1660H009',
#    'WaterLevel': 4.89},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1730H076',
#    'WaterLevel': 58.07},
#   {'RecordTime': 'Dec 8, 2019 12:10:00 AM',
#    'StationIdentifier': '1510H063',
#    'WaterLevel': 263.89},
#   {'RecordTime': 'Dec 8, 2019 12:00:00 AM',
#    'StationIdentifier': '2200H021',
#    'WaterLevel': 369.66},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1630H020',
#    'WaterLevel': 35.31},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1430H054',
#    'WaterLevel': 48.26},
#   {'RecordTime': 'Dec 8, 2019 12:00:00 AM',
#    'StationIdentifier': '1730H045',
#    'WaterLevel': 5.17},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1650H014',
#    'WaterLevel': 1.05},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1730H071',
#    'WaterLevel': 35.3},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1510H050',
#    'WaterLevel': 155.66},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1740H007',
#    'WaterLevel': 0.73},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1590H019',
#    'WaterLevel': 14.96},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1430H032',
#    'WaterLevel': 337.6},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1730H036',
#    'WaterLevel': 107.44},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1630H037',
#    'WaterLevel': 9.33},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1730H067',
#    'WaterLevel': -999998},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1430H057',
#    'WaterLevel': 31.73},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1730H079',
#    'WaterLevel': 548.87},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1590H016',
#    'WaterLevel': 11.32},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1430H028',
#    'WaterLevel': 23.6},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1540H031',
#    'WaterLevel': 10.18},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1510H084',
#    'WaterLevel': 145.07},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': 25.74},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1430H052',
#    'WaterLevel': 173.12},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1590H012',
#    'WaterLevel': 2.91},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1510H081',
#    'WaterLevel': 229.1},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1430H025',
#    'WaterLevel': 10.03},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1540H014',
#    'WaterLevel': 8.07},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1630H013',
#    'WaterLevel': 15.58},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1550H014',
#    'WaterLevel': 26.77},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1430H048',
#    'WaterLevel': 166.07},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1580H007',
#    'WaterLevel': 23.7},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1510H057',
#    'WaterLevel': 88.54},
#   {'RecordTime': 'Dec 5, 2019 4:00:00 AM',
#    'StationIdentifier': '1420H056',
#    'WaterLevel': 196.29},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1510H087',
#    'WaterLevel': 428.61},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1580H020',
#    'WaterLevel': 35.82},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1550H011',
#    'WaterLevel': 0.23},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1510H082',
#    'WaterLevel': 752.41},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1430H038',
#    'WaterLevel': 74.69},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1430H046',
#    'WaterLevel': 111.1},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1140H107',
#    'WaterLevel': 4.09},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1430H061',
#    'WaterLevel': 24.96},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1580H013',
#    'WaterLevel': 9.78},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1540H038',
#    'WaterLevel': 54.81},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1510H076',
#    'WaterLevel': 4.88},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1430H030',
#    'WaterLevel': 87.68},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1430H044',
#    'WaterLevel': 139.49},
#   {'RecordTime': 'Dec 8, 2019 12:10:00 AM',
#    'StationIdentifier': '1140H101',
#    'WaterLevel': 182.25},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1430H060',
#    'WaterLevel': 20.1},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1550H018',
#    'WaterLevel': -0.08},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1540H033',
#    'WaterLevel': 23.33},
#   {'RecordTime': 'Dec 8, 2019 12:10:00 AM',
#    'StationIdentifier': '1510H064',
#    'WaterLevel': 265.06},
#   {'RecordTime': 'Dec 8, 2019 12:10:00 AM',
#    'StationIdentifier': '1420H053',
#    'WaterLevel': 471.68},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1290H004',
#    'WaterLevel': 115.7},
#   {'RecordTime': 'Dec 8, 2019 12:10:00 AM',
#    'StationIdentifier': '1140H076',
#    'WaterLevel': 135.72},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1430H055',
#    'WaterLevel': 78.58},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1540H036',
#    'WaterLevel': 0.06},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1510H088',
#    'WaterLevel': 141.11},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1350H019',
#    'WaterLevel': 33.75},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1400H020',
#    'WaterLevel': 318.66},
#   {'RecordTime': 'Dec 8, 2019 12:00:00 AM',
#    'StationIdentifier': '1140H098',
#    'WaterLevel': 174.89},
#   {'RecordTime': 'Dec 8, 2019 12:10:00 AM',
#    'StationIdentifier': '1140H048',
#    'WaterLevel': 28.73},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1300H024',
#    'WaterLevel': 28.93},
#   {'RecordTime': 'Dec 8, 2019 12:10:00 AM',
#    'StationIdentifier': '1420H052',
#    'WaterLevel': 429.6},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1510H085',
#    'WaterLevel': 279.86},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1340H013',
#    'WaterLevel': 247.1},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '1400H018',
#    'WaterLevel': 55.24},
#   {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#    'StationIdentifier': '2560H006',
#    'WaterLevel': 3.72}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}

# %%
json.loads(b.text)['value'][0]
# Out:
# {'RecordTime': 'Dec 8, 2019 12:20:00 AM',
#  'StationIdentifier': '1680H004',
#  'WaterLevel': 1.09}
